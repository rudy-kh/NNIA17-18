# %% [markdown]
# # Assignment Sheet 6:  Regularization methods in Machine learning and their application in Feedforward neural networks  (deadline: 16 Dec, 23:59)

# %% [markdown]
# ### General Regularization methods in ML $~$ (5 points)

# %% [markdown]
# **Goal:** Study the effects of **L2** and **L1** regularization on the weights used for modelling the data.

# %% [markdown]
# ***Ridge regression*** is very similar to least squares, except that the weights are estimated by minimizing a slightly different quantity. In particular, the ridge regression co-efficient estimates $\mathbf{W_{ridge}}$ are the values that minimize,
#
# $$\mathbf{J(W) ~~=~~ \big|\big|~Y-XW~\big|\big|_{2}^2 ~+~\lambda~ \big|\big|~W~\big|\big|_{2}^2}$$
#
# where,
#
# $\mathbf{\lambda>0}$ is the regularizer,
#
# **X** is the design matrix,
#
# $\mathbf{W}$ is the weight vector and
#
# **Y** represents the responses.

# %% [markdown]
# ***Ridge regression*** seeks weight estimate $W^{Ridge}$ that fit the data well by minimizing the squared error $~$ $\mathbf{||~Y-XW~||^2}$ (which was also the linear regression cost function).
# However, the second term, $\mathbf{||~W~||^2}$, called a ***shrinkage penalty*** is small when $\mathbf{W}$, i.e., $(w_1, w_2, ..., w_d)^T$ are close to zero. Thus, it has the effect of shrinking the estimates of $w_i$ towards zero.
#
# The regularizer $\mathbf{\lambda}$ serves to control the relative impact of these two terms on the regression weight estimates. when $\mathbf{\lambda=0}$, the penalty term has no effect, and ridge regression will produce the least squares estimates. However, as $\mathbf{\lambda \rightarrow \infty}$, the impact of the shrinkage penalty grows and the ridge regression weight estimates will approach zero. Unlike least squares, which generates only one set of weight estimates, ridge regression will produce a different set of weight estimates, $\mathbf{W_{\lambda}^{Ridge}}$, for each value of $\mathbf{\lambda}$. Hence, selecting a good value of $\mathbf{\lambda}$ is critical.

# %% [markdown]
# $1.$ **Plot the magnitude of each weight in $\mathbf{W^{Ridge}}$ vs $\mathbf{\lambda}$ and explain how the regularizer $\mathbf{\lambda}$ affects the Ridge weights $\mathbf{W^{Ridge}}$.** $~$ ($2.5$ points)
#
# Download the dataset, **data.csv**, from the NNIA piazza page.

# %%
# Load libraries
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.preprocessing import scale 
from sklearn.linear_model import Ridge, Lasso

# %matplotlib inline

plt.rcParams["figure.figsize"] = [12, 9]

# %%
# Read data
# TODO Implement
data = pd.read_csv('data.csv')
# Read 'Salary' as your response/dependent variable
# TODO Implement
responses = data['Salary'].as_matrix()

# Drop the column with the dependent variable 'Salary'
# We can also drop player name as each column is unique
variables = data.drop(['Salary', 'Player'], axis = 1).as_matrix()

variables.shape
# Out:
# (263, 19)

# %%
# Initialize values for the alphas
lamdas = 10**np.linspace(10,-2,100)*0.5
# Create a Ridge Object that performs ridge regression
# TODO Implement
model = Ridge(fit_intercept = False)
# Create list to hold ridge weights
# TODO Implement
weights_ridges = []
# Iterate over all lamdas, performing data fitting with ridge regression 
# and find the corresponding co-efficients
#TODO Implement
for i in range(len(lamdas)):
    model.alpha = lamdas[i]
    model.fit(variables, responses)
    weights_ridges.append(model.coef_)

# Generate the plot
# TODO Implement

print(weights_ridges[0].shape)

ax = plt.gca()
ax.plot(lamdas, weights_ridges)
ax.set_xscale('log')
plt.axis('tight')

# Name the plot
# TODO Implement
plt.xlabel('lamdas')
plt.ylabel('weights')
plt.title('weights vs lamdas')
plt.show()
# Out:
# (19,)

# %%
# Now generate the same plot as above using Tensorflow
# for the same set of lambdas
# TODO: implement the function below.
responses_tf = np.reshape(responses, newshape=(-1, 1))

input_shape = (None, variables.shape[1])
output_shape = (None, 1)

inputs = tf.placeholder("float", input_shape)
outputs = tf.placeholder("float", output_shape)
lamda = tf.placeholder("float")

W = tf.get_variable("W", [variables.shape[1], 1], dtype=tf.float32, initializer=tf.random_normal_initializer())
b = tf.get_variable("b", 1, initializer=tf.constant_initializer(0.01))
with tf.variable_scope("model") as scope:
    predictions = tf.matmul(inputs, W)
    l2_loss = tf.nn.l2_loss(outputs - predictions)
    regularizer = tf.nn.l2_loss(W)
    loss = tf.reduce_mean(l2_loss + lamda * regularizer)

# shuffle only the training data along axis 0
#def shuffle_train_data(X_train, Y_train):
    #"""called after each epoch"""
    #perm = np.random.permutation(len(Y_train))
    #Xtr_shuf = X_train[perm]
    #Ytr_shuf = Y_train[perm]
    
    #return Xtr_shuf, Ytr_shuf

absolute_learning_rate = 5e-3
optimizer = []
train_op = []
for i in range (len(lamdas)):
    optimizer.append(tf.train.GradientDescentOptimizer(absolute_learning_rate / lamdas[i]))
    train_op.append(optimizer[i].minimize(loss)) 

epochs = 10
batch_size = 10

n = variables.shape[0]
init = tf.global_variables_initializer()

weights_ridges_tf = []

with tf.Session() as sess:
    # iterate for every lambda
    for i in range(len(lamdas)):
        sess.run(init)
        print("Doing training for lambda = {:.9f}".format(lamdas[i]))
        # TODO: Perform training
        for epoch in range(epochs):
            #X_train_epoch, y_train_epoch = shuffle_train_data(X_train, y_train)
            bs = 0
            while bs < n:
                if(n - bs > batch_size):
                    X_batch = variables[bs : bs + batch_size,]
                    y_batch = responses_tf[bs : bs + batch_size,]
                else:
                    X_batch = variables[bs : n, ]
                    y_batch = responses_tf[bs : n, ]
                
                _, batch_loss= sess.run([train_op[i],loss], feed_dict={inputs: X_batch, outputs: y_batch, lamda: lamdas[i]})
                
                bs += batch_size
            
            epoch_loss = sess.run(loss, feed_dict={inputs: variables, outputs: responses_tf, lamda: lamdas[i]})
            print("Epoch:", '%04d' % (epoch+1), "error={:.2f}".format(epoch_loss))
            
        weights_ridges_tf.append(W.eval())
# Out:
# Doing training for lambda = 5000000000.000000000
# Epoch: 0001 error=28875714560.00
# Epoch: 0002 error=22056198144.00
# Epoch: 0003 error=16852385792.00
# Epoch: 0004 error=12881252352.00
# Epoch: 0005 error=9850613760.00
# Epoch: 0006 error=7537565696.00
# Epoch: 0007 error=5772055552.00
# Epoch: 0008 error=4424346624.00
# Epoch: 0009 error=3395460096.00
# Epoch: 0010 error=2609879552.00
# Doing training for lambda = 3782316637.773145199
# Epoch: 0001 error=17469495296.00
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 352.740115536
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 266.834961560
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 201.850862930
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 152.692775442
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 115.506485004
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 87.376420000
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 66.097057423
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 50.000000000
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 37.823166378
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 28.611838297
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 21.643806405
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 16.372745814
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 12.385381780
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 9.369087114
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 7.087370815
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 5.361336110
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 4.055654154
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 3.067953637
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 2.320794417
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 1.755595867
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 1.328043891
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 1.004616501
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.759955541
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.574878498
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.434874501
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.328966612
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.248851178
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.188246790
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.142401793
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.107721735
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.081487542
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.061642337
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.046630167
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.035274012
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.026683496
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.020185086
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.015269278
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.011550649
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.008737642
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.006609706
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.005000000
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan

# %%
# Generate the plot
# TODO Implement

for i in range(len(weights_ridges_tf)):
    weights_ridges_tf[i] = weights_ridges_tf[i].ravel()
    
ax = plt.gca()
ax.plot(lamdas, weights_ridges_tf)
ax.set_xscale('log')
plt.axis('tight')

# Name the plot
# TODO Implement
plt.xlabel('lamdas')
plt.ylabel('weights')
plt.title('weights vs lamdas')
plt.show()

# %% [markdown]
# $2$. Next we deal with **L1 regularization** for which the corresponding method is called **Lasso.** In Lasso, we minimize the function,
# $$\mathbf{J(W) ~~=~~ \big|\big|~Y-XW~\big|\big|_{2}^2 ~+~\lambda~ \big|\big|~W~\big|\big|_{1}}$$

# %% [markdown]
# **Plot the magnitude of each weight in $\mathbf{W^{Lasso}}$ vs $\mathbf{\lambda}$ and explain how the regularizer $\mathbf{\lambda}$ affects the Lasso weights $\mathbf{W^{Lasso}}$.** $~$ ($2.5$ points)

# %%
# Create a Lasso Object(set max_iter to 10000)
# TODO Implement
model_lasso = Lasso(max_iter=10000)
# Create list to hold lasso weights
# TODO Implement
weights_lasso = []
# Iterate over all alphas, performing data fitting with Lasso
# and find the corresponding co-efficients
# TODO Implement
for i in range(len(lamdas)):
    model_lasso.alpha = lamdas[i]
    model_lasso.fit(variables, responses)
    weights_lasso.append(model_lasso.coef_)

# Generate the plot
# TODO Implement

ax = plt.gca()
ax.plot(lamdas, weights_lasso)
ax.set_xscale('log')
plt.axis('tight')

# Name the plot
# TODO Implement
plt.xlabel('lamdas')
plt.ylabel('weights')
plt.title('weights vs lamdas on lasso regularizer')
plt.show()

# %%
with tf.variable_scope("model_lasso") as scope:
    predictions = tf.matmul(inputs, W)
    l2_loss = tf.nn.l2_loss(outputs - predictions)
    l1_regularizer = tf.norm(W, ord= 1)
    loss = tf.reduce_mean(l2_loss + lamda * l1_regularizer)

# shuffle only the training data along axis 0
#def shuffle_train_data(X_train, Y_train):
    #"""called after each epoch"""
    #perm = np.random.permutation(len(Y_train))
    #Xtr_shuf = X_train[perm]
    #Ytr_shuf = Y_train[perm]
    
    #return Xtr_shuf, Ytr_shuf

absolute_learning_rate = 5e-2
optimizer = []
train_op = []
for i in range (len(lamdas)):
    optimizer.append(tf.train.GradientDescentOptimizer(absolute_learning_rate / lamdas[i]))
    train_op.append(optimizer[i].minimize(loss)) 

epochs = 10
batch_size = 10

n = variables.shape[0]
init = tf.global_variables_initializer()

weights_lassos_tf = []

with tf.Session() as sess:
    # iterate for every lambda
    for i in range(len(lamdas)):
        sess.run(init)
        print("Doing training for lambda = {:.9f}".format(lamdas[i]))
        # TODO: Perform training
        for epoch in range(epochs):
            #X_train_epoch, y_train_epoch = shuffle_train_data(X_train, y_train)
            bs = 0
            while bs < n:
                if(n - bs > batch_size):
                    X_batch = variables[bs : bs + batch_size,]
                    y_batch = responses_tf[bs : bs + batch_size,]
                else:
                    X_batch = variables[bs : n, ]
                    y_batch = responses_tf[bs : n, ]
                
                _, batch_loss= sess.run([train_op[i],loss], feed_dict={inputs: X_batch, outputs: y_batch, lamda: lamdas[i]})
                
                bs += batch_size
            
            epoch_loss = sess.run(loss, feed_dict={inputs: variables, outputs: responses_tf, lamda: lamdas[i]})
            print("Epoch:", '%04d' % (epoch+1), "error={:.2f}".format(epoch_loss))
            
        weights_lassos_tf.append(W.eval())
# Out:
# Doing training for lambda = 5000000000.000000000
# Epoch: 0001 error=12290349056.00
# Epoch: 0002 error=1805814784.00
# Epoch: 0003 error=3084454912.00
# Epoch: 0004 error=1750856192.00
# Epoch: 0005 error=3129337088.00
# Epoch: 0006 error=1831987072.00
# Epoch: 0007 error=3028622592.00
# Epoch: 0008 error=1915039360.00
# Epoch: 0009 error=2937038592.00
# Epoch: 0010 error=1988468224.00
# Doing training for lambda = 3782316637.773145199
# Epoch: 0001 error=8818528256.00
# Epoch: 0002 error=1734826880.00
# Epoch: 0003 error=1972886144.00
# Epoch: 0004 error=1789897472.00
# Epoch: 0005 error=1903273856.00
# Epoch: 0006 error=1840658944.00
# Epoch: 0007 error=1840790400.00
# Epoch: 0008 error=1887374208.00
# Epoch: 0009 error=1821593600.00
# Epoch: 0010 error=1889532288.00
# Doing training for lambda = 2861183829.675109863
# Epoch: 0001 error=3482104576.00
# Epoch: 0002 error=1393054720.00
# Epoch: 0003 error=1481422464.00
# Epoch: 0004 error=1335339136.00
# Epoch: 0005 error=1516847488.00
# Epoch: 0006 error=1315774848.00
# Epoch: 0007 error=1513854848.00
# Epoch: 0008 error=1363691776.00
# Epoch: 0009 error=1447879808.00
# Epoch: 0010 error=1407405312.00
# Doing training for lambda = 2164380640.541530609
# Epoch: 0001 error=5527424512.00
# Epoch: 0002 error=860561856.00
# Epoch: 0003 error=1456830336.00
# Epoch: 0004 error=703618368.00
# Epoch: 0005 error=1477847936.00
# Epoch: 0006 error=770199424.00
# Epoch: 0007 error=1377937024.00
# Epoch: 0008 error=879515840.00
# Epoch: 0009 error=1343622144.00
# Epoch: 0010 error=834821440.00
# Doing training for lambda = 1637274581.438865900
# Epoch: 0001 error=3014268416.00
# Epoch: 0002 error=906956544.00
# Epoch: 0003 error=855734528.00
# Epoch: 0004 error=780441344.00
# Epoch: 0005 error=941108672.00
# Epoch: 0006 error=753220928.00
# Epoch: 0007 error=918456448.00
# Epoch: 0008 error=762510592.00
# Epoch: 0009 error=986800832.00
# Epoch: 0010 error=643343680.00
# Doing training for lambda = 1238538177.995857000
# Epoch: 0007 error=3045315474966495302273065728081920.00
# Epoch: 0008 error=9255328096091240860522779303533871104.00
# Epoch: 0009 error=inf
# Epoch: 0010 error=inf
# Doing training for lambda = 2018508.629298275
# Epoch: 0001 error=148485438933009694720.00
# Epoch: 0002 error=298605528528590414851364465147904.00
# Epoch: 0003 error=inf
# Epoch: 0004 error=inf
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 1526927.754416706
# Epoch: 0001 error=7906688576529864798849227292672.00
# Epoch: 0002 error=inf
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 1155064.850041579
# Epoch: 0001 error=inf
# Epoch: 0002 error=inf
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 873764.200003841
# Epoch: 0001 error=inf
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 660970.574233014
# Epoch: 0001 error=inf
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 500000.000000000
# Epoch: 0001 error=inf
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 378231.663777315
# Epoch: 0001 error=inf
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 286118.382967511
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 216438.064054153
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 163727.458143886
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 123853.817799585
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 93690.871143019
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 70873.708146340
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 53613.361100516
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 40556.541539484
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 30679.536367066
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 23207.944168064
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 17555.958671076
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 13280.438914733
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 10046.165012825
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 7599.555414765
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 5748.784976989
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 4348.745013089
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 3289.666123288
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 2488.511782166
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 1882.467903396
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 1424.017934218
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 1077.217345016
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 814.875417310
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 616.423369721
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 466.301673442
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 352.740115536
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 266.834961560
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 201.850862930
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 152.692775442
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 115.506485004
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 87.376420000
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 66.097057423
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 50.000000000
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 37.823166378
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 28.611838297
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 21.643806405
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 16.372745814
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 12.385381780
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 9.369087114
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 7.087370815
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 5.361336110
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 4.055654154
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 3.067953637
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 2.320794417
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 1.755595867
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 1.328043891
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 1.004616501
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.759955541
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.574878498
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.434874501
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.328966612
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.248851178
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.188246790
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.142401793
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.107721735
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.081487542
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.061642337
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.046630167
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.035274012
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.026683496
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.020185086
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.015269278
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.011550649
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.008737642
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.006609706
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan
# Doing training for lambda = 0.005000000
# Epoch: 0001 error=nan
# Epoch: 0002 error=nan
# Epoch: 0003 error=nan
# Epoch: 0004 error=nan
# Epoch: 0005 error=nan
# Epoch: 0006 error=nan
# Epoch: 0007 error=nan
# Epoch: 0008 error=nan
# Epoch: 0009 error=nan
# Epoch: 0010 error=nan

# %%
# Generate the plot
# TODO Implement

for i in range(len(weights_ridges_tf)):
    weights_lassos_tf[i] = weights_lassos_tf[i].ravel()
    
ax = plt.gca()
ax.plot(lamdas, weights_lassos_tf)
ax.set_xscale('log')
plt.axis('tight')

# Name the plot
# TODO Implement
plt.xlabel('lamdas')
plt.ylabel('weights')
plt.title('weights vs lamdas')
plt.show()

# %% [markdown]
# **Comment on the plots generated in problems $1$ and $2$ respectively.**

# %% [markdown]
# ### Understanding the Impact of norms in the  Regularizer $~$ (4 points)

# %% [markdown]
# $4$. Assume$~$ $\mathbf{x} \in R^2$, $(x_1, x_2) \in [-1, 1]\times[-1, 1]$. $~$ (2 points)

# %% [markdown]
# Now, draw the contour plots for $\mathbf{\big|\big|~x~\big|\big|_{0}}$, $\mathbf{\big|\big|~x~\big|\big|_{1}}$, $\mathbf{\big|\big|~x~\big|\big|_{2}}$ and $\mathbf{\big|\big|~x~\big|\big|_{\infty}}$ norms (consider all possible isolines in the given interval,i.e., ($[-1,1]\times[-1,1]$) and **explain** how you get the corresponding plot, i.e., provide the mathematical formula for getting the outermost isoline in each case.
#
# ![image1](https://i.imgur.com/RD5pynL.jpg)

# %% [markdown]
# $5$. Sketch the **Lasso** optimization function, $~$ $\mathbf{J(W) ~~=~~ \big|\big|~Y-XW~\big|\big|_{2}^2 ~+~\lambda~ \big|\big|~W~\big|\big|_{1}}$ $~$ in two dimensions. From this sketch try to explain why **Lasso** induces **sparsity.** $~$ (2 points)
#
# ![image2](https://i.imgur.com/jGHd9yG.jpg)

# %% [markdown]
# ### Getting to know Back-Propagation in details $~$ (3 points)

# %% [markdown]
# ![Neural Network](https://github.com/mmarius/nnia-tutorial/blob/master/neural-net.png?raw=true)

# %% [markdown]
# We have a **Feedforward Neural network** with one **input layer**, one **hidden layer** and one **output layer.** The **hidden layer** and **output layer** use the sigmoid function, $\mathbf{\sigma(x) = \frac{1}{1+exp(-x)}}$, as **activation function.** Also note, that the network minimizes **Binary Cross Entropy loss**, given by, $$\mathbf{J = \sum -y\log(\hat{y}) - (1-y)\log(1-\hat{y})}$$
#
# We consider the true class labels to be **binary**, i.e., either $0$ or $1$.

# %% [markdown]
# **For the purpose of computing the derivatives of the loss/cost function consider the numerical values obtained by the network.**

# %% [markdown]
# **Input layer** consists of two nodes, $x_1$ and $x_2$ respectively. For our problem consider the following input,
# $$\begin{bmatrix} x_1\\ x_2\\ \end{bmatrix} = \begin{bmatrix} -1\\ 1\\ \end{bmatrix}$$

# %% [markdown]
# **Hidden layer** is made up of 3 neurons and the corresponding matrix of weights is as given:
# $$
# \mathbf{W_{hidden}}
# ~=~
# \begin{bmatrix} w_1^{1} & w_1^{2} & w_1^{3} \\ w_2^{1} & w_2^{2} & w_2^{3} \end{bmatrix}
# ~=~
# \begin{bmatrix} 0.15 & -0.25 & 0.05\\ 0.20 & 0.10 & -0.15 \end{bmatrix}
# $$
#
# **Note:** Output of **Hidden layer** is given by, $~~$ $\mathbf{a=\sigma~(W_{hidden}^{T}x)}$

# %% [markdown]
# **Output layer** consists of one neuron, i.e., the **network** generates a single output. **For our problem, the true class label is $1$.**

# %% [markdown]
# The matrix corresponding to the **Output layer** is given by,
# $$
# \mathbf{W_{out}}
# ~=~
# \begin{bmatrix} w_1\\w_2 \\w_3\end{bmatrix}
# ~=~
# \begin{bmatrix} 0.20\\-0.35\\0.15 \end{bmatrix}
# $$
#
# **Note:** output from the **Output layer** is given by, $~$ $\mathbf{\hat{y} = \sigma~(W_{out}^Ta)}$

# %% [markdown]
# $6$. Execute the following sequence of operations and **show that Binary Cross Entropy loss is getting reduced, i.e., $ C^2 < C^1$** $~$ ($3$ points)
#
# **Perform Forward-propagation to generate output** $\to$ **Compute loss or cost ($C^1$)** $\to$ **perform Back-propagation to compute the error** $\to$ **perform Gradient descent to update the weights** $\to$ **peform Forward-propagation again with updated weights** $\to$ **Compute loss or cost ($C^2$)**

# %% [markdown]
# **Note:**  $C^i$ denotes the loss or cost at the $i^{th}$ iteration, for performing Gradient descent consider a learning rate of $0.1$

# %%
from IPython.display import Image
Image(url="https://raw.githubusercontent.com/rudy-kh/NNIA17-18/master/assignment%206/images/3_1.jpg")
# Out:
# <img src="https://raw.githubusercontent.com/rudy-kh/NNIA17-18/master/assignment%206/images/3_1.jpg"/>

# %%
Image(url="https://raw.githubusercontent.com/rudy-kh/NNIA17-18/master/assignment%206/images/3_2.jpg")
# Out:
# <img src="https://raw.githubusercontent.com/rudy-kh/NNIA17-18/master/assignment%206/images/3_2.jpg"/>

# %%
Image(url="https://raw.githubusercontent.com/rudy-kh/NNIA17-18/master/assignment%206/images/3_3.jpg")
# Out:
# <img src="https://raw.githubusercontent.com/rudy-kh/NNIA17-18/master/assignment%206/images/3_3.jpg"/>

# %% [markdown]
# ### Feed-forward Neural Network with L1 and L2 regularization $~$ (8 points)

# %% [markdown]
# In the following exercise you would build a **feed-forward network** from scratch using only **Numpy** in python. For this, you also have to implement **Back-propagation** in python. Additionally, this network should have the option of **L1 and L2 regularization** enabled within it.

# %% [markdown]
# Download **mnist** dataset from NNIA piazza page.

# %%
import os
import struct
import numpy as np
 
def load_mnist(path, kind='train'):
    """function for loading data"""
    labels_path = os.path.join(path, 
                               '%s-labels-idx1-ubyte' % kind)
    images_path = os.path.join(path, 
                               '%s-images-idx3-ubyte' % kind)
        
    with open(labels_path, 'rb') as lbpath:
        magic, n = struct.unpack('>II', 
                                 lbpath.read(8))
        labels = np.fromfile(lbpath, 
                             dtype=np.uint8)

    with open(images_path, 'rb') as imgpath:
        magic, num, rows, cols = struct.unpack(">IIII", 
                                               imgpath.read(16))
        images = np.fromfile(imgpath, 
                             dtype=np.uint8).reshape(len(labels), 784)
 
    return images, labels

# %%
X_train, y_train = load_mnist('mnist/', kind='train')
print('Rows: %d, columns: %d' % (X_train.shape[0], X_train.shape[1]))
# Out:
# Rows: 60000, columns: 784

# %%
X_test, y_test = load_mnist('mnist/', kind='t10k')
print('Rows: %d, columns: %d' % (X_test.shape[0], X_test.shape[1]))
# Out:
# Rows: 10000, columns: 784

# %%
import numpy as np
from scipy.special import expit


class MLP(object):
    """ Feedforward neural network with a single hidden layer.

    Parameters
    ------------
    n_output : int
        Number of output units, should be equal to the
        number of unique class labels. 
        
    n_features : int
        Number of features (dimensions) in the target dataset.
        Should be equal to the number of columns in the X array.
        
    n_hidden : int
        Number of hidden units.
        
    l1 : float
        Regularizer for L1-regularization.
        l1=0.0 implies no regularization
        
    l2 : float
        Lambda value for L2-regularization.
        l2=0.0 implies no regularization
        
    epochs : int
        Number of passes over the training set.
        
    eta : float (default: 0.001)
        Learning rate.
        
    decrease_const : float (default: 0.0)
        Decrease constant. Shrinks the learning rate
        after each epoch via eta / (1 + epoch*decrease_const)
        
    shuffle : bool (default: True)
        Shuffles training data every epoch if True to prevent circles.
        
    minibatches : int (default: 1)
        Divides training data into k minibatches for efficiency.
        
    random_state : int (default: None)
        Set random state for shuffling and initializing the weights.

    Attributes
    -----------
    cost_ : list
      Sum of squared errors after each epoch.

    """
    def __init__(self, n_output, n_features, n_hidden=30,
                 l1=0.0, l2=0.0, epochs=50, eta=0.001,
                 decrease_const=0.0, shuffle=True,
                 minibatches=1, random_state=None):
        
        #TODO Implement
        np.random.seed(random_state)
        self.n_output = n_output # np.unique(labels)
        self.n_features = n_features
        self.n_hidden = n_hidden
        self.l1 = l1
        self.l2 = l2
        self.epochs = epochs
        self.eta = eta
        self.decrease_const = decrease_const
        self.shuffle = shuffle
        self.minibatches = minibatches
        self.w1, self.w2 = self.initialize_weights()


    def encode_labels(self, y, k):
        """Encode the labels using one-hot representation

        Parameters
        ------------
        y : y represents target values.

        Returns
        -----------
        onehot array

        """
        #TODO Implement
        onehot = np.zeros((k, y.shape[0]))
        for i, val in enumerate(y):
            onehot[val, i] = 1.0
        return onehot
        
        return one_hot_targets
        

    def initialize_weights(self):
        """Initialize using random numbers."""
        
        #TODO Implement
        w1 = np.random.uniform(-1.0, 1.0, size=self.n_hidden*(self.n_features + 1))
        w1 = w1.reshape(self.n_hidden, self.n_features + 1)
        w2 = np.random.uniform(-1.0, 1.0, size=self.n_output*(self.n_hidden + 1))
        w2 = w2.reshape(self.n_output, self.n_hidden + 1)
        return w1, w2

    def sigmoid(self, z):
        """Compute sigmoid function
           Implement a stable version which 
           takes care of overflow and underflow.
        """
        
        #TODO Implement
        return expit(z)
        

    def sigmoid_gradient(self, z):
        """Compute gradient of the sigmoid function"""
        
        #TODO Implement
        sig = self.sigmoid(z)
        return sig * (1.0 - sig)
        

    def add_bias_unit(self, X, how='column'):
        """Add bias unit to array at index 0"""
        
        #TODO Implement
        
        if how == 'column':
            X_new = np.ones((X.shape[0], X.shape[1] + 1))
            X_new[:, 1:] = X
        elif how == 'row':
            X_new = np.ones((X.shape[0] + 1, X.shape[1]))
            X_new[1:, :] = X
        
        return X_new
        
        

    def feedforward(self, X, w1, w2):
        """Compute feedforward step

        Parameters
        -----------
        X : array, shape = [n_samples, n_features]
            Input layer with original features.
        w1 : array, shape = [n_hidden_units, n_features]
            Weight matrix for input layer -> hidden layer.
        w2 : array, shape = [n_output_units, n_hidden_units]
            Weight matrix for hidden layer -> output layer.

        Returns
        ----------
        a1 : array,
            Input values with bias unit.
        z2 : array,
            Net input of hidden layer.
        a2 : array,
            Activation of hidden layer.
        z3 : array,
            Net input of output layer.
        a3 : array,
            Activation of output layer.

        """
        
        # TODO Implement
        a1 = self.add_bias_unit(X, how='column')
        z2 = w1.dot(a1.T)
        a2 = self.sigmoid(z2)
        a2 = self.add_bias_unit(a2, how='row')
        z3 = w2.dot(a2)
        a3 = self.sigmoid(z3)
        return a1, z2, a2, z3, a3
        #linear_model = self.sigmoid(np.dot(w1, X))
        #output = self.sigmoid(np.dot(linear_model, w2))
        #return output
        

    def L2_reg(self, lambda_, w1, w2):
        """Compute L2-regularization cost"""
        
        #TODO Implement
        l2_reg = (lambda_ /2.0) * (np.sum(w1[:, 1:] ** 2) + np.sum(w2[:, 1:] ** 2))
        return  l2_reg 
        
        

    def L1_reg(self, lambda_, w1, w2):
        """Compute L1-regularization cost"""
        
        #TODO Implement
        l1_reg = (lambda_ /2.0) * (np.abs(w1[:, 1:]).sum() + np.abs(w2[:, 1:]).sum())
        return l1_reg
        
    def get_cost(self, y_enc, output, w1, w2):
        """Compute cost function.

        Parameters
        ----------
        y_enc : array, one-hot encoded class labels.
        
        output : array, Activation of the output layer (feedforward)
        
        w1 : array, Weight matrix for input layer -> hidden layer.
        w2 : array, Weight matrix for hidden layer -> output layer.

        Returns
        ---------
        cost : float, Regularized cost.

        """
        
        #TODO Implement
        term1 = -y_enc * (np.log(output))
        term2 = (1.0 - y_enc) * np.log(1.0 - output)
        cost = np.sum(term1 - term2)
        l1_reg = self.L1_reg(self.l1, w1, w2)
        l2_reg = self.L2_reg(self.l2, w1, w2)
        cost = cost + l1_reg + l2_reg
        return cost
        
        

    def get_gradient(self, a1, a2, a3, z2, y_enc, w1, w2):
        """ Compute gradient step using backpropagation.

        Parameters
        ------------
        a1 : array, Input values with bias unit.
        a2 : array, Activation of hidden layer.
        a3 : array, Activation of output layer.
        z2 : array, Net input of hidden layer.
        y_enc : array, one-hot encoded class labels.
        w1 : array, Weight matrix for input layer -> hidden layer.
        w2 : array, Weight matrix for hidden layer -> output layer.

        Returns
        ---------
        grad1 : array, Gradient of the weight matrix w1.
        grad2 : array, Gradient of the weight matrix w2.

        """
        
        # backpropagation
        #TODO Implement
        output_layer = a3 - y_enc
        z2 = self.add_bias_unit(z2, how='row')
        hidden_layer = w2.T.dot(output_layer) * self.sigmoid_gradient(z2)
        hidden_layer = hidden_layer[1:, :]
        grad1 = hidden_layer.dot(a1)
        grad2 = output_layer.dot(a2.T)
        

        # regularize
        #TODO Implement
        grad1[:, 1:] += self.l2 * w1[:, 1:]
        grad1[:, 1:] += self.l1 * np.sign(w1[:, 1:])
        grad2[:, 1:] += self.l2 * w2[:, 1:]
        grad2[:, 1:] += self.l1 * np.sign(w2[:, 1:])

        return grad1, grad2

    def predict(self, X):
        """Predict class labels

        Parameters
        -----------
        X : array, Input layer with original features.

        Returns:
        ----------
        y_pred : array, Predicted class labels.

        """
        # TODO Implement
        
        a1, z2, a2, z3, a3 = self.feedforward(X, self.w1, self.w2)
        y_pred = np.argmax(z3, axis=0)
        return y_pred

        
    def fit(self, X, y, print_progress=False):
        """ Learn weights from training data.

        Parameters
        -----------
        X : array, Input layer with original features.
        y : array, Target class labels.
        print_progress : bool, Prints the progress

        Returns:
        ----------
        self

        """
        #w1=self.w1
        #w2=self.w2
        #print (w1, w2)
        #TODO Implement
        self.cost_ = []
        X_data, y_data = X.copy(), y.copy()
        y_enc = self.encode_labels(y, self.n_output)

        w1_prev = np.zeros(self.w1.shape)
        w2_prev = np.zeros(self.w2.shape)

        for i in range(self.epochs):

            # adaptive learning rate
            self.eta /= (1 + self.decrease_const*i)

            if print_progress:
                print('\rEpoch: %d/%d' % (i+1, self.epochs))

            if self.shuffle:
                idx = np.random.permutation(y_data.shape[0])
                X_data, y_enc = X_data[idx], y_enc[:, idx]

            mini = np.array_split(range(y_data.shape[0]), self.minibatches)
            for idx in mini:

                # feedforward
                a1, z2, a2, z3, a3 = self.feedforward(X_data[idx], self.w1, self.w2)
                cost = self.get_cost(y_enc[:, idx], a3, self.w1, self.w2)
                self.cost_.append(cost)

                # backpropagation
                grad1, grad2 = self.get_gradient(a1=a1, a2=a2,
                                                  a3=a3, z2=z2,
                                                  y_enc=y_enc[:, idx],
                                                  w1=self.w1,
                                                  w2=self.w2)

                d_w1, d_w2 = self.eta * grad1, self.eta * grad2
                self.w1 -= (d_w1 + (self.eta * w1_prev))
                self.w2 -= (d_w2 + (self.eta * w2_prev))
                w1_prev, w2_prev = d_w1, d_w2

        return self

# %%
nn = MLP(n_output=10, 
                  n_features=X_train.shape[1], 
                  n_hidden=50, 
                  l2=0.1, 
                  l1=0.0, 
                  epochs=1000, 
                  eta=0.001,
                  decrease_const=0.00001,
                  minibatches=50, 
                  shuffle=True,
                  random_state=1)

# %%
nn.fit(X_train, y_train, print_progress=True)
# Out:
# Epoch: 1/1000
# Epoch: 2/1000
# Epoch: 3/1000
# Epoch: 4/1000
# Epoch: 5/1000
# Epoch: 6/1000
# Epoch: 7/1000
# Epoch: 8/1000
# Epoch: 9/1000
# Epoch: 10/1000
# Epoch: 11/1000
# Epoch: 12/1000
# Epoch: 13/1000
# Epoch: 14/1000
# Epoch: 15/1000
# Epoch: 16/1000
# Epoch: 17/1000
# Epoch: 18/1000

# %%
import matplotlib.pyplot as plt

# Plot the training error for every iteration
# in every epoch

# TODO Implement
plt.plot(range(len(nn.cost_)), nn.cost_)
plt.ylim([0, 2000])
plt.ylabel('Cost')
plt.xlabel('Epochs * 50')
plt.tight_layout()
plt.show()

# %%
# Plot the training error in every epoch
# TODO Implement
n_batches = np.array_split(range(len(nn.cost_)), 1000)
costs = np.array(nn.cost_)
cost_avgs = [np.mean(costs[i]) for i in n_batches]
plt.plot(range(len(cost_avgs)), cost_avgs, color='red')
plt.ylim([0, 2000])
plt.ylabel('Cost')
plt.xlabel('Epochs')
plt.tight_layout()
plt.show()

# %%
# Compute Training Accuracy
# TODO Implement
y_train_pred = nn.predict(X_train)

#if sys.version_info < (3, 0):
acc = ((np.sum(y_train == y_train_pred, axis=0)).astype('float') / X_train.shape[0])
#acc = np.sum(y_train == y_train_pred, axis=0) / X_train.shape[0]
print('Training accuracy: %.2f%%' % (acc * 100))

# %%
# Compute Test Accuracy
# TODO Implement
y_test_pred = nn.predict(X_test)


acc = ((np.sum(y_test == y_test_pred, axis=0)).astype('float') / X_test.shape[0])
#acc = np.sum(y_test == y_test_pred, axis=0) / X_test.shape[0]
print('Test accuracy: %.2f%%' % (acc * 100))
